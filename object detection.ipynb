# %%
! pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in c:\users\dell\appdata\roaming\python\python39\site-packages (4.10.0.82)
# Requirement already satisfied: numpy>=1.19.3 in c:\programdata\anaconda3\lib\site-packages (from opencv-python) (1.21.5)

# %%
! pip install ultralytics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ultralytics
#   Using cached ultralytics-8.2.28-py3-none-any.whl (779 kB)
# Requirement already satisfied: seaborn>=0.11.0 in c:\programdata\anaconda3\lib\site-packages (from ultralytics) (0.11.2)
# Requirement already satisfied: tqdm>=4.64.0 in c:\programdata\anaconda3\lib\site-packages (from ultralytics) (4.64.0)
# Collecting ultralytics-thop>=0.2.5
#   Using cached ultralytics_thop-0.2.7-py3-none-any.whl (25 kB)
# Requirement already satisfied: scipy>=1.4.1 in c:\programdata\anaconda3\lib\site-packages (from ultralytics) (1.7.3)
# Requirement already satisfied: pandas>=1.1.4 in c:\programdata\anaconda3\lib\site-packages (from ultralytics) (1.4.2)
# Requirement already satisfied: psutil in c:\programdata\anaconda3\lib\site-packages (from ultralytics) (5.8.0)
# Requirement already satisfied: pillow>=7.1.2 in c:\programdata\anaconda3\lib\site-packages (from ultralytics) (9.0.1)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\dell\appdata\roaming\python\python39\site-packages (from ultralytics) (4.10.0.82)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\programdata\anaconda3\lib\site-packages (from ultralytics) (3.5.1)
# Requirement already satisfied: requests>=2.23.0 in c:\programdata\anaconda3\lib\site-packages (from ultralytics) (2.27.1)
# Collecting torch>=1.8.0
#   Using cached torch-2.3.0-cp39-cp39-win_amd64.whl (159.7 MB)
# Collecting torchvision>=0.9.0
#   Using cached torchvision-0.18.0-cp39-cp39-win_amd64.whl (1.2 MB)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\programdata\anaconda3\lib\site-packages (from ultralytics) (6.0)
# Collecting py-cpuinfo
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: numpy>=1.17 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2.11.3)
# Collecting typing-extensions>=4.8.0
#   Using cached typing_extensions-4.12.1-py3-none-any.whl (37 kB)
# Collecting mkl<=2021.4.0,>=2021.1.1
#   Downloading mkl-2021.4.0-py2.py3-none-win_amd64.whl (228.5 MB)
# Requirement already satisfied: fsspec in c:\programdata\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2022.2.0)
# Requirement already satisfied: sympy in c:\programdata\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (1.10.1)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2.7.1)
# Collecting intel-openmp==2021.*
#   Downloading intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl (3.5 MB)
# Collecting tbb==2021.*
#   Downloading tbb-2021.12.0-py3-none-win_amd64.whl (286 kB)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in c:\programdata\anaconda3\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.2.1)
# Installing collected packages: tbb, intel-openmp, typing-extensions, mkl, torch, ultralytics-thop, torchvision, py-cpuinfo, ultralytics
# Successfully installed intel-openmp-2021.4.0 mkl-2021.4.0 py-cpuinfo-9.0.0 tbb-2021.12.0 torch-2.3.0 torchvision-0.18.0 typing-extensions-4.12.1 ultralytics-8.2.28 ultralytics-thop-0.2.7
#   WARNING: The scripts convert-caffe2-to-onnx.exe, convert-onnx-to-caffe2.exe and torchrun.exe are installed in 'C:\Users\Dell\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script cpuinfo.exe is installed in 'C:\Users\Dell\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts ultralytics.exe and yolo.exe are installed in 'C:\Users\Dell\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
from ultralytics import YOLO
import cv2
import math 

cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

model = YOLO("yolo-Weights/yolov8n.pt")

classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier","pen"
              ]


while True:
    success, img = cap.read()
    results = model(img, stream=True)

    for r in results:
        boxes = r.boxes

        for box in boxes:
    
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 686.2ms
# Speed: 22.4ms preprocess, 686.2ms inference, 29.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 airplane, 725.5ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.34
# Class name --> aeroplane
# Confidence ---> 0.28
# Class name --> person
# Speed: 24.4ms preprocess, 725.5ms inference, 25.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 309.1ms
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 5.6ms preprocess, 309.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 301.8ms
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Speed: 2.9ms preprocess, 301.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 258.1ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 1.2ms preprocess, 258.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 281.0ms
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Speed: 8.0ms preprocess, 281.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 252.3ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Speed: 2.1ms preprocess, 252.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 284.5ms
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Speed: 1.2ms preprocess, 284.5ms inference, 17.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 221.4ms
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Speed: 2.7ms preprocess, 221.4ms inference, 12.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 baseball bat, 246.0ms
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.32
# Class name --> baseball bat
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.7ms preprocess, 246.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 271.5ms
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 0.0ms preprocess, 271.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 baseball bat, 1 cell phone, 254.6ms
# Confidence ---> 0.64
# Class name --> baseball bat
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.26
# Class name --> cell phone
# Speed: 0.0ms preprocess, 254.6ms inference, 16.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 316.4ms
# Confidence ---> 0.93
# Class name --> cell phone
# Confidence ---> 0.36
# Class name --> person
# Speed: 1.3ms preprocess, 316.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 remote, 1 cell phone, 220.1ms
# Confidence ---> 0.7
# Class name --> cell phone
# Confidence ---> 0.61
# Class name --> remote
# Speed: 0.0ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 294.4ms
# Confidence ---> 0.82
# Class name --> cell phone
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 4.5ms preprocess, 294.4ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 remote, 1 cell phone, 283.2ms
# Confidence ---> 0.67
# Class name --> remote
# Confidence ---> 0.48
# Class name --> cell phone
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 3.0ms preprocess, 283.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 242.9ms
# Confidence ---> 0.7
# Class name --> cell phone
# Confidence ---> 0.49
# Class name --> remote
# Confidence ---> 0.4
# Class name --> person
# Speed: 0.0ms preprocess, 242.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 remote, 1 cell phone, 213.6ms
# Confidence ---> 0.73
# Class name --> cell phone
# Confidence ---> 0.48
# Class name --> remote
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 3.1ms preprocess, 213.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 347.8ms
# Confidence ---> 0.59
# Class name --> remote
# Confidence ---> 0.56
# Class name --> cell phone
# Confidence ---> 0.31
# Class name --> person
# Speed: 3.6ms preprocess, 347.8ms inference, 13.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 270.7ms
# Confidence ---> 0.8
# Class name --> cell phone
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.0ms preprocess, 270.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 245.9ms
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 7.1ms preprocess, 245.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 knife, 293.2ms
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.32
# Class name --> knife
# Speed: 0.0ms preprocess, 293.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 240.0ms
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 7.7ms preprocess, 240.0ms inference, 15.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 253.2ms
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Speed: 0.0ms preprocess, 253.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 310.1ms
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Speed: 2.5ms preprocess, 310.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 249.3ms
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Speed: 3.3ms preprocess, 249.3ms inference, 14.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 251.3ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Speed: 1.1ms preprocess, 251.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 299.3ms
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 4.7ms preprocess, 299.3ms inference, 15.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 268.1ms
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 4.5ms preprocess, 268.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 250.6ms
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Speed: 4.2ms preprocess, 250.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 263.7ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Speed: 7.5ms preprocess, 263.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 231.6ms
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Speed: 0.0ms preprocess, 231.6ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 290.7ms
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Speed: 2.5ms preprocess, 290.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 262.5ms
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Speed: 0.0ms preprocess, 262.5ms inference, 11.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 237.4ms
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Speed: 3.0ms preprocess, 237.4ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 241.0ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Speed: 3.2ms preprocess, 241.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 313.5ms
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Speed: 1.7ms preprocess, 313.5ms inference, 17.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 215.9ms
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Speed: 6.1ms preprocess, 215.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 272.4ms
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 0.0ms preprocess, 272.4ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 skateboard, 300.3ms
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.32
# Class name --> skateboard
# Confidence ---> 0.28
# Class name --> person
# Speed: 3.8ms preprocess, 300.3ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 234.3ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 4.6ms preprocess, 234.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 213.0ms
# Confidence ---> 0.62
# Class name --> person
# Speed: 3.6ms preprocess, 213.0ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 300.8ms
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 1.8ms preprocess, 300.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 221.6ms
# Confidence ---> 0.44
# Class name --> person
# Speed: 0.0ms preprocess, 221.6ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 252.4ms
# Confidence ---> 0.44
# Class name --> person
# Speed: 4.6ms preprocess, 252.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 293.9ms
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Speed: 0.0ms preprocess, 293.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 312.9ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.39
# Class name --> bottle
# Speed: 6.1ms preprocess, 312.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 250.5ms
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.37
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> person
# Speed: 3.4ms preprocess, 250.5ms inference, 13.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 249.6ms
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.43
# Class name --> bottle
# Confidence ---> 0.4
# Class name --> person
# Speed: 4.9ms preprocess, 249.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 250.2ms
# Confidence ---> 0.57
# Class name --> bottle
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 4.3ms preprocess, 250.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 240.6ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.52
# Class name --> bottle
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 0.0ms preprocess, 240.6ms inference, 15.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bottle, 260.9ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> person
# Speed: 5.3ms preprocess, 260.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bottle, 1 toothbrush, 238.6ms
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.45
# Class name --> pen
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 0.5ms preprocess, 238.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 bottle, 220.3ms
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.41
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 2.9ms preprocess, 220.3ms inference, 13.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 toothbrush, 334.3ms
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.44
# Class name --> pen
# Confidence ---> 0.36
# Class name --> person
# Speed: 2.5ms preprocess, 334.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 toothbrush, 250.4ms
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.3
# Class name --> pen
# Speed: 2.3ms preprocess, 250.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1 remote, 274.3ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.53
# Class name --> remote
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 3.3ms preprocess, 274.3ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1 remote, 1 cell phone, 284.6ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.49
# Class name --> remote
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.41
# Class name --> cell phone
# Confidence ---> 0.28
# Class name --> bottle
# Speed: 2.5ms preprocess, 284.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 remote, 315.2ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.26
# Class name --> remote
# Speed: 2.1ms preprocess, 315.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1 cup, 1 cell phone, 287.9ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.43
# Class name --> cell phone
# Confidence ---> 0.43
# Class name --> cup
# Confidence ---> 0.42
# Class name --> bottle
# Speed: 9.4ms preprocess, 287.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 281.5ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Speed: 6.6ms preprocess, 281.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 256.9ms
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Speed: 8.5ms preprocess, 256.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 286.8ms
# Confidence ---> 0.44
# Class name --> person
# Speed: 2.1ms preprocess, 286.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 228.6ms
# Confidence ---> 0.34
# Class name --> person
# Speed: 7.0ms preprocess, 228.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 243.5ms
# Confidence ---> 0.52
# Class name --> person
# Speed: 2.3ms preprocess, 243.5ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 278.7ms
# Confidence ---> 0.37
# Class name --> person
# Speed: 5.6ms preprocess, 278.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 228.4ms
# Confidence ---> 0.76
# Class name --> person
# Speed: 8.6ms preprocess, 228.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 285.5ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 0.0ms preprocess, 285.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 221.5ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 1.2ms preprocess, 221.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 393.6ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Speed: 3.7ms preprocess, 393.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 241.6ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Speed: 5.1ms preprocess, 241.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 239.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Speed: 0.0ms preprocess, 239.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 289.4ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Speed: 0.0ms preprocess, 289.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 253.8ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Speed: 0.0ms preprocess, 253.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 307.1ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Speed: 0.0ms preprocess, 307.1ms inference, 11.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 251.5ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Speed: 0.0ms preprocess, 251.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 292.1ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Speed: 2.7ms preprocess, 292.1ms inference, 7.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 231.8ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Speed: 0.0ms preprocess, 231.8ms inference, 14.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 246.8ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Speed: 6.8ms preprocess, 246.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 333.9ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Speed: 0.0ms preprocess, 333.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 258.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 5.2ms preprocess, 258.7ms inference, 14.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 297.4ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 2.9ms preprocess, 297.4ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 253.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Speed: 0.0ms preprocess, 253.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 232.4ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 4.7ms preprocess, 232.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 235.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Speed: 2.9ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 287.4ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Speed: 0.0ms preprocess, 287.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 274.4ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Speed: 4.2ms preprocess, 274.4ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 263.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Speed: 5.8ms preprocess, 263.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 246.5ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Speed: 4.7ms preprocess, 246.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 239.8ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Speed: 2.0ms preprocess, 239.8ms inference, 14.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 246.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Speed: 0.0ms preprocess, 246.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 315.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Speed: 3.3ms preprocess, 315.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 286.8ms
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Speed: 0.0ms preprocess, 286.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 251.9ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Speed: 2.6ms preprocess, 251.9ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 252.3ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Speed: 1.1ms preprocess, 252.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 237.7ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Speed: 3.1ms preprocess, 237.7ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 229.4ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Speed: 2.6ms preprocess, 229.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 221.2ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Speed: 1.7ms preprocess, 221.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 remote, 1 cell phone, 298.8ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.42
# Class name --> cell phone
# Confidence ---> 0.34
# Class name --> remote
# Speed: 1.2ms preprocess, 298.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 remote, 267.0ms
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.27
# Class name --> remote
# Speed: 1.1ms preprocess, 267.0ms inference, 16.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons,
0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Speed: 2.6ms preprocess, 324.0ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 327.3ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Speed: 2.0ms preprocess, 327.3ms inference, 14.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 247.9ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 4.4ms preprocess, 247.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 237.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Speed: 2.8ms preprocess, 237.3ms inference, 13.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 236.2ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Speed: 2.0ms preprocess, 236.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 250.2ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Speed: 1.8ms preprocess, 250.2ms inference, 14.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 292.4ms
# Confidence ---> 0.61
# Class name --> person
# Speed: 2.6ms preprocess, 292.4ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 267.3ms
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.49
# Class name --> bottle
# Speed: 7.4ms preprocess, 267.3ms inference, 10.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 268.5ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.33
# Class name --> cat
# Speed: 3.3ms preprocess, 268.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 250.9ms
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 1.8ms preprocess, 250.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 282.0ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.0ms preprocess, 282.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 273.9ms
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Speed: 3.8ms preprocess, 273.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 206.9ms
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 2.3ms preprocess, 206.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 244.6ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Speed: 6.8ms preprocess, 244.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 266.7ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Speed: 2.9ms preprocess, 266.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 336.0ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Speed: 4.9ms preprocess, 336.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 265.2ms
# Confidence ---> 0.78
# Class name --> person
# ...
#
# 0: 480x640 3 persons, 233.8ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Speed: 4.0ms preprocess, 233.8ms inference, 14.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 236.5ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Speed: 2.7ms preprocess, 236.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 249.6ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Speed: 2.6ms preprocess, 249.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 224.6ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 6.1ms preprocess, 224.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 283.1ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 2.6ms preprocess, 283.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 231.0ms
# Confidence ---> 0.69
# Class name --> person
# Speed: 1.3ms preprocess, 231.0ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 285.7ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.8ms preprocess, 285.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 235.8ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Speed: 6.0ms preprocess, 235.8ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 331.6ms
# Confidence ---> 0.74
# Class name --> person
# Speed: 0.0ms preprocess, 331.6ms inference, 13.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 267.9ms
# Confidence ---> 0.74
# Class name --> person
# Speed: 3.1ms preprocess, 267.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 238.6ms
# Confidence ---> 0.75
# Class name --> person
# Speed: 0.0ms preprocess, 238.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 245.2ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 0.0ms preprocess, 245.2ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 267.3ms
# Confidence ---> 0.74
# Class name --> person
# Speed: 2.5ms preprocess, 267.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 298.6ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 2.0ms preprocess, 298.6ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 220.5ms
# Confidence ---> 0.72
# Class name --> person
# Speed: 0.0ms preprocess, 220.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 284.0ms
# Confidence ---> 0.7
# Class name --> person
# Speed: 2.7ms preprocess, 284.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 253.2ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 0.0ms preprocess, 253.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 219.1ms
# Confidence ---> 0.7
# Class name --> person
# Speed: 4.7ms preprocess, 219.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 278.7ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Speed: 2.5ms preprocess, 278.7ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 235.3ms
# Confidence ---> 0.71
# Class name --> person
# Speed: 4.1ms preprocess, 235.3ms inference, 11.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 246.7ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 6.2ms preprocess, 246.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 236.2ms
# Confidence ---> 0.65
# Class name --> person
# Speed: 3.8ms preprocess, 236.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 275.6ms
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 5.1ms preprocess, 275.6ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 296.0ms
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 5.0ms preprocess, 296.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 235.9ms
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Speed: 2.4ms preprocess, 235.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 220.7ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 1.4ms preprocess, 220.7ms inference, 15.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 310.5ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.8
# Class name --> person
# Speed: 5.0ms preprocess, 310.5ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 286.7ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Speed: 5.3ms preprocess, 286.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 242.0ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Speed: 5.8ms preprocess, 242.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 278.7ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Speed: 3.0ms preprocess, 278.7ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 535.1ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Speed: 12.0ms preprocess, 535.1ms inference, 11.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 336.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.8
# Class name --> person
# Speed: 7.7ms preprocess, 336.3ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 231.6ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Speed: 6.3ms preprocess, 231.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 257.7ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Speed: 1.6ms preprocess, 257.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 318.8ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Speed: 0.0ms preprocess, 318.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 265.1ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Speed: 4.7ms preprocess, 265.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 277.6ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Speed: 2.7ms preprocess, 277.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 259.1ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Speed: 1.4ms preprocess, 259.1ms inference, 9.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 301.7ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.8
# Class name --> person
# Speed: 0.0ms preprocess, 301.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 228.8ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Speed: 5.0ms preprocess, 228.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 353.8ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Speed: 2.2ms preprocess, 353.8ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 25>()
#      25 success, img = cap.read()
#      26 results = model(img, stream=True)
# ---> 28 for r in results:
#      29     boxes = r.boxes
#      31     for box in boxes:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\utils\_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ultralytics\engine\predictor.py:248, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     246 # Inference
#     247 with profilers[1]:
# --> 248     preds = self.inference(im, *args, **kwargs)
#     249     if self.args.embed:
#     250         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ultralytics\engine\predictor.py:142, in BasePredictor.inference(self, im, *args, **kwargs)
#     136 """Runs inference on a given image using the specified model and arguments."""
#     137 visualize = (
#     138     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     139     if self.args.visualize and (not self.source_type.tensor)
#     140     else False
#     141 )
# --> 142 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ultralytics\nn\autobackend.py:453, in AutoBackend.forward(self, im, augment, visualize, embed)
#     451 # PyTorch
#     452 if self.pt or self.nn_module:
# --> 453     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     455 # TorchScript
#     456 elif self.jit:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ultralytics\nn\tasks.py:89, in BaseModel.forward(self, x, *args, **kwargs)
#      87 if isinstance(x, dict):  # for cases of training and validating while training.
#      88     return self.loss(x, *args, **kwargs)
# ---> 89 return self.predict(x, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ultralytics\nn\tasks.py:107, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     105 if augment:
#     106     return self._predict_augment(x)
# --> 107 return self._predict_once(x, profile, visualize, embed)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ultralytics\nn\tasks.py:128, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     126 if profile:
#     127     self._profile_one_layer(m, x, dt)
# --> 128 x = m(x)  # run
#     129 y.append(x if m.i in self.save else None)  # save output
#     130 if visualize:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ultralytics\nn\modules\conv.py:54, in Conv.forward_fuse(self, x)
#      52 def forward_fuse(self, x):
#      53     """Perform transposed convolution of 2D data."""
# ---> 54     return self.act(self.conv(x))
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\activation.py:396, in SiLU.forward(self, input)
#     395 def forward(self, input: Tensor) -> Tensor:
# --> 396     return F.silu(input, inplace=self.inplace)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\functional.py:2101, in silu(input, inplace)
#    2099     return handle_torch_function(silu, (input,), input, inplace=inplace)
#    2100 if inplace:
# -> 2101     return torch._C._nn.silu_(input)
#    2102 return torch._C._nn.silu(input)
#
# KeyboardInterrupt:
